# %%
import pandas as pd

df = pd.read_csv("student-mat.csv")

df.sample(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 272     GP   F   18       U     LE3       T     1     1     other     other
# 370     MS   F   19       U     LE3       T     3     2  services  services
# 249     GP   M   16       U     GT3       T     0     2     other     other
# 146     GP   F   15       U     GT3       T     3     2    health  services
# 190     GP   F   16       U     GT3       T     2     3  services  services
# 384     MS   M   18       R     GT3       T     4     2     other     other
# 254     GP   M   17       R     GT3       T     2     1     other     other
# 373     MS   F   17       R     GT3       T     1     2     other     other
# 38      GP   F   15       R     GT3       T     3     4  services    health
# 236     GP   M   17       U     LE3       T     2     2     other     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
higher_medu=df["Medu"]>2
dalc_higher_medu=df.loc[higher_medu, "Dalc"].mean()
dalc_higher_medu
# Out:
# 1.5260869565217392

# %%
df.loc[df["Medu"]>2, "Dalc"].mean()
# Out:
# 1.5260869565217392

# %%
df.loc[higher_medu, ["Dalc", "Walc"] ]
# Out:
#      Dalc  Walc
# 0       1     1
# 3       1     1
# 4       1     2
# 5       1     2
# 7       1     1
# ..    ...   ...
# 384     4     3
# 386     2     2
# 388     1     1
# 391     3     4
# 393     3     4
#
# [230 rows x 2 columns]

# %%
df["Dalc"]+df["Walc"]
# Out:
# 0      2
# 1      2
# 2      5
# 3      2
# 4      3
#       ..
# 390    9
# 391    7
# 392    6
# 393    7
# 394    6
# Length: 395, dtype: int64

# %%
df["sum_alc"]=df["Dalc"]+df["Walc"]
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 sum_alc
# 0        3     4     1     1       3        6   5   6   6       2
# 1        3     3     1     1       3        4   5   5   6       2
# 2        3     2     2     3       3       10   7   8  10       5
# 3        2     2     1     1       5        2  15  14  15       2
# 4        3     2     1     2       5        4   6  10  10       3
#
# [5 rows x 34 columns]

# %%
df.loc[:, ["Fjob", "Mjob"]].value_counts()
# Out:
# Fjob      Mjob
# other     other       104
# services  services     43
# other     services     42
#           at_home      33
# services  other        24
# other     teacher      21
# services  teacher      19
# other     health       17
# services  at_home      15
# teacher   teacher      12
# services  health       10
# teacher   services      8
# at_home   at_home       7
# health    health        6
# at_home   services      6
# teacher   other         6
# at_home   other         5
# health    teacher       4
#           services      4
#           other         2
#           at_home       2
# at_home   teacher       2
# teacher   at_home       2
#           health        1
# dtype: int64
